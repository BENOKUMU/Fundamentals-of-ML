# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
x = np.linspace(-3,3,1000) # 1000 sample number btw -3 t 3

# %%
# plot subplot
fig, ((ax1, ax2, ax3), (ax4, ax5, ax6)) = plt.subplots(nrows=2, ncols=3)

# %%
# plot subplot
fig, ((ax1, ax2, ax3), (ax4, ax5, ax6)) = plt.subplots(nrows=2, ncols=3)
ax1.plot(x, x)
ax1.set_title('linear')
ax2.plot(x, x**2)
ax2.set_title('degree 2')
ax3.plot(x, x**3)
ax3.set_title('degree 3')
ax4.plot(x, x**4)
ax4.set_title('degree 4')
ax5.plot(x, x**5)
ax5.set_title('degree 5')
ax6.plot(x, x**6)
ax6.set_title('degree 6')

plt.tight_layout()# tidy layout

# %%
df = pd.read_csv('Salary.csv')

# %%
df.describe()
# Out:
#        YearsExperience         Salary
# count        35.000000      35.000000
# mean          6.308571   83945.600000
# std           3.618610   32162.673003
# min           1.100000   37731.000000
# 25%           3.450000   57019.000000
# 50%           5.300000   81363.000000
# 75%           9.250000  113223.500000
# max          13.500000  139465.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  35 non-null     float64
#  1   Salary           35 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 688.0 bytes

# %%
# simple scatter plot
df.plot(kind = 'scatter', x='YearsExperience', y='Salary', title='Salary vs YearsExperience')
# Out:
# <AxesSubplot:title={'center':'Salary vs YearsExperience'}, xlabel='YearsExperience', ylabel='Salary'>

# %%
# check the correlation between the variables
print("Correlation matrix: ")
df.corr()
# Out:
# Correlation matrix:
#                  YearsExperience    Salary
# YearsExperience         1.000000  0.982427
# Salary                  0.982427  1.000000

# %%
from sklearn.linear_model import LinearRegression

# %%
# create linear regression object
lm = LinearRegression()

# %%
X = df.YearsExperience[:, np.newaxis]
y = df.Salary
# Out:
# C:\Users\benja\AppData\Local\Temp/ipykernel_11308/4045891805.py:1: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   X = df.YearsExperience[:, np.newaxis]

# %% [markdown]
# lm.fit(X, y)

# %%
lm.fit(X, y)
# Out:
# LinearRegression()

# %%
# plotting fitted line
plt.scatter(X, y, color='black')
plt.plot(X, lm.predict(X), color='blue', linewidth=3)
plt.title('Salary vs YearsExperience')
plt.ylabel('Salary')
plt.xlabel('YearsExperience')
# Out:
# Text(0.5, 0, 'YearsExperience')

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11308/1374001828.py in <module>
# ----> 1 print( "R Squared: ", r2_score(y, lm.predict(X)))
#
# NameError: name 'r2_score' is not defined
